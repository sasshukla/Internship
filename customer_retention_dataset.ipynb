# %% [markdown]
# ### Importing the basic libraries

# %%
import pandas as pd
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

# %%
### Importing  the dataset 
#### Importing the training dataset
df=pd.read_excel(r'C:\Users\DELL\Downloads\Customer_retention_dataset_1\Customer_retention_dataset\customer_retention_dataset.xlsx')
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
### Checking the size of the dataset 
df.shape
# Out:
# (269, 71)

# %%
### As there are 71 column. So, I am setting option to display all cloumns and row with pandas
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %% [markdown]
# ### First I will change the respective column name to alias names.

# %%
dict={'1Gender of respondent':'Gender', 
      '2 How old are you? ':'Age',
       '3 Which city do you shop online from?':'City',
       '4 What is the Pin Code of where you shop online from?':'Pin',
       '5 Since How Long You are Shopping Online ?':'Shopping Since',
       '6 How many times you have made an online purchase in the past 1 year?':'Purchase in past 1 Year',
       '7 How do you access the internet while shopping on-line?':'Internet service used',
       '8 Which device do you use to access the online shopping?':'Device',     
      '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ':'Screen Size of used device',
      '10 What is the operating system (OS) of your device?\t\t\t\t                                          ':'Device OS',
       '11 What browser do you run on your device to access the website?\t\t\t                                                          ':'Browser',
       '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ':'Channel which direct to website',
       '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ':'How to reach store',
       '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ':'Time taken to make decision',
       '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ':'Payment Option',
       '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ':'Abandon',
       '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ':'Reson of Abandon',
       '18 The content on the website must be easy to read and understand':'what Content easy to read?',
       '19 Information on similar product to the one highlighted  is important for product comparison':'Information need to highlight for comparison',
       '20 Complete information on listed seller and product being offered is important for purchase decision.':'Important information of seller',
       '21 All relevant information on listed products must be stated clearly':'Information need to state clearly',
       '22 Ease of navigation in website':'Ease of Negative', '23 Loading and processing speed':'Speed',
       '24 User friendly Interface of the website':'Interface',
       '25 Convenient Payment methods':'Convenient Payment option',
       '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time':'Trust on transaction',
       '27 Empathy (readiness to assist with queries) towards the customers':'Empathy',
       '28 Being able to guarantee the privacy of the customer':'Privacy guarantee',
       '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)':'Res, Avail of communication',
       '30 Online shopping gives monetary benefit and discounts':'Benefit and Discounts',
       '31 Enjoyment is derived from shopping online':'Enjoyment',
       '32 Shopping online is convenient and flexible':'Convenient and Flexible',
       '33 Return and replacement policy of the e-tailer is important for purchase decision':'Is return, replace important',
       '34 Gaining access to loyalty programs is a benefit of shopping online':'Loyalty Programs Benefits',
       '35 Displaying quality Information on the website improves satisfaction of customers':'Displaying Information',
       '36 User derive satisfaction while shopping on a good quality website or application':'Good Quality Website',
       '37 Net Benefit derived from shopping online can lead to users satisfaction':'Net Benefit',
       '38 User satisfaction cannot exist without trust':'Satisfaction/Trust',
       '39 Offering a wide variety of listed product in several category':'Wide variety',
       '40 Provision of complete and relevant product information':'Relevant product information',
       '41 Monetary savings':'Monetary savings',
       '42 The Convenience of patronizing the online retailer':'Patronizing',
       '43 Shopping on the website gives you the sense of adventure':'Sense of Adventure',
       '44 Shopping on your preferred e-tailer enhances your social status':'Preferred e-tailer',
       '45 You feel gratification shopping on your favorite e-tailer':'Gratification',
       '46 Shopping on the website helps you fulfill certain roles':'Helps you fulfill certain roles',
       '47 Getting value for money spent':'Value for money spent',
       'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ':'Tick',           
       'Easy to use website or application':'Website/Application',
       'Visual appealing web-page layout':'Web-page Layout', 'Wild variety of product on offer':'Wild variety',
       'Complete, relevant description information of products':'Product Information',
       'Fast loading website speed of website and application':'Website loading speed',
       'Reliability of the website or application':'Reliability',
       'Quickness to complete purchase':'Quickness to purchase',
       'Availability of several payment options':'several payment options', 'Speedy order delivery':'Speed Order delivery',
       'Privacy of customers’ information':'Privacy',
       'Security of customer financial information':'Security for financial info',
       'Perceived Trustworthiness':'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel':'Online assistance',
       'Longer time to get logged in (promotion, sales period)':'Time to get logged',
       'Longer time in displaying graphics and photos (promotion, sales period)':'Time in displaying graphics',
       'Late declaration of price (promotion, sales period)':'Late declaration of price',
       'Longer page loading time (promotion, sales period)':'Page loading time',
       'Limited mode of payment on most products (promotion, sales period)':'Limited mode of payment',
       'Longer delivery period':'Delivery period', 'Change in website/Application design':'Change in website/Application',
       'Frequent disruption when moving from one page to another':'Frequent disruption',
       'Website is as efficient as before':'efficient as before',
       'Which of the Indian online retailer would you recommend to a friend?':'Recommend Indian online retailer'}

# %%
### set the alias name of the columns
df.rename(columns=dict, inplace=True)

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'City', 'Pin', 'Shopping Since',
#        'Purchase in past 1 Year', 'Internet service used', 'Device',
#        'Screen Size of used device', 'Device OS', 'Browser',
#        'Channel which direct to website', 'How to reach store',
#        'Time taken to make decision', 'Payment Option', 'Abandon',
#        'Reson of Abandon', 'what Content easy to read?',
#        'Information need to highlight for comparison',
#        'Important information of seller', 'Information need to state clearly',
#        'Ease of Negative', 'Speed', 'Interface', 'Convenient Payment option',
#        'Trust on transaction', 'Empathy', 'Privacy guarantee',
#        'Res, Avail of communication', 'Benefit and Discounts', 'Enjoyment',
#        'Convenient and Flexible', 'Is return, replace important',
#        'Loyalty Programs Benefits', 'Displaying Information',
#        'Good Quality Website', 'Net Benefit', 'Satisfaction/Trust',
# ...

# %%
### Changed the dataset columns with its respective alias name.
df.head()
# Out:
#    Gender          Age           City     Pin Shopping Since  \
# 0    Male  31-40 years          Delhi  110009  Above 4 years
# 1  Female  21-30 years          Delhi  110030  Above 4 years
# 2  Female  21-30 years  Greater Noida  201308      3-4 years
# 3    Male  21-30 years        Karnal   132001      3-4 years
# 4  Female  21-30 years     Bangalore   530068      2-3 years
#
#   Purchase in past 1 Year Internet service used      Device  \
# 0             31-40 times               Dial-up     Desktop
# 1      41 times and above                 Wi-Fi  Smartphone
# 2      41 times and above       Mobile Internet  Smartphone
# 3      Less than 10 times       Mobile Internet  Smartphone
# 4             11-20 times                 Wi-Fi  Smartphone
#
#   Screen Size of used device              Device OS        Browser  \
# 0                     Others  Window/windows Mobile  Google chrome
# 1                 4.7 inches                IOS/Mac  Google chrome
# ...

# %%
### Checking the null values 
df.isna().sum()
# Out:
# Gender                                          0
# Age                                             0
# City                                            0
# Pin                                             0
# Shopping Since                                  0
# Purchase in past 1 Year                         0
# Internet service used                           0
# Device                                          0
# Screen Size of used device                      0
# Device OS                                       0
# Browser                                         0
# Channel which direct to website                 0
# How to reach store                              0
# Time taken to make decision                     0
# Payment Option                                  0
# Abandon                                         0
# Reson of Abandon                                0
# what Content easy to read?                      0
# Information need to highlight for comparison    0
# ...

# %%
### Checking the dataset details like - Null valuse and datatype of values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Gender                                        269 non-null    object
#  1   Age                                           269 non-null    object
#  2   City                                          269 non-null    object
#  3   Pin                                           269 non-null    int64
#  4   Shopping Since                                269 non-null    object
#  5   Purchase in past 1 Year                       269 non-null    object
#  6   Internet service used                         269 non-null    object
#  7   Device                                        269 non-null    object
#  8   Screen Size of used device                    269 non-null    object
# ...

# %% [markdown]
# ### There is no null values in the dataset. Now moving ahead to perform EDA.
#
# ## EDA

# %% [markdown]
# ### As there are 71 columns. So, I will divide the columns in four part and form the EDA

# %%
### Importing the basic visualization matrix
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
### Countplot to see the count of values
df['Gender'].value_counts()
sns.countplot("Gender", data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Conclusion- Females is doing more shopping comparison to the male.

# %%
### Countplot to see the count of values
df['Age'].value_counts()
plt.figure(figsize=(10,8))
sns.countplot("Age", data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# ### Conclusion- Consumner from the age 21 to 50 doing more shopping. I can say this range should be target audiance.

# %%
### Countplot to see the count of values
df['City'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("City", data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %% [markdown]
# ### Conclusion- Consumer from the Metro cities doing more shopping comparison to small town and small cities.

# %%
### Countplot to see the count of values
df['Shopping Since'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Shopping Since", data=df)
# Out:
# <AxesSubplot:xlabel='Shopping Since', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of the consumer doing shopping since 4 year I can say every day these number are increasing.

# %%
### Countplot to see the count of values
df['Purchase in past 1 Year'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Purchase in past 1 Year", data=df)
# Out:
# <AxesSubplot:xlabel='Purchase in past 1 Year', ylabel='count'>

# %% [markdown]
# ### Conclusion- Mostly consumer doing less than 10 purchase with in year but purchase 31- 40 is aslo good count.

# %%
### Countplot to see the count of values
df['Screen Size of used device'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Screen Size of used device", data=df)
# Out:
# <AxesSubplot:xlabel='Screen Size of used device', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of the consumer are not sure about the screen size but approx all user uses device with 4.7- 5.5 inches screen size device.

# %%
### Countplot to see the count of values
df['Internet service used'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Internet service used", data=df)
# Out:
# <AxesSubplot:xlabel='Internet service used', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of the consumer using Mobile and Wi-Fi in which there are more cosumer which is using mobile internet for shopping.

# %%
### Countplot to see the count of values
df['Device'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Device", data=df)
# Out:
# <AxesSubplot:xlabel='Device', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of the consumer using smartphone and laptop for shopping.

# %%
### Countplot to see the count of values
df['Device OS'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Device OS", data=df)
# Out:
# <AxesSubplot:xlabel='Device OS', ylabel='count'>

# %% [markdown]
# ### Conclusion- All Operating system has their category to do shopping but consumer with Windows and Android has good capacity to do shopping.

# %%
### Countplot to see the count of values
df['Browser'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Browser", data=df)
# Out:
# <AxesSubplot:xlabel='Browser', ylabel='count'>

# %% [markdown]
# ### Conclusion- Google chrome has great plaform to do online shopping comparison to other browser.

# %%
### Countplot to see the count of values
df['Channel which direct to website'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Channel which direct to website", data=df)
# Out:
# <AxesSubplot:xlabel='Channel which direct to website', ylabel='count'>

# %% [markdown]
# ### Conclusion- Search Engine has directed more consumer to online shopping platform.

# %%
### Countplot to see the count of values
df['How to reach store'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("How to reach store", data=df)
# Out:
# <AxesSubplot:xlabel='How to reach store', ylabel='count'>

# %% [markdown]
# ### Conclusion- Search Engine, Application and direct URL has directed more consumer to online shopping store.

# %%
### Countplot to see the count of values
df['Time taken to make decision'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Time taken to make decision", data=df)
# Out:
# <AxesSubplot:xlabel='Time taken to make decision', ylabel='count'>

# %% [markdown]
# ### Conclusion- Consumers taking more than 15 mins to take decision to do shopping.

# %%
### Countplot to see the count of values
df['Payment Option'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Payment Option", data=df)
# Out:
# <AxesSubplot:xlabel='Payment Option', ylabel='count'>

# %% [markdown]
# ### Conclusion- Consumers like to do payment through Credit and debit card and COD consumer has good number to do payment.

# %%
### Countplot to see the count of values
df['Abandon'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Abandon", data=df)
# Out:
# <AxesSubplot:xlabel='Abandon', ylabel='count'>

# %% [markdown]
# ### Conclusion- There are less number of consumer which quit shopping website.

# %%
### Countplot to see the count of values
df['Reson of Abandon'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Reson of Abandon", data=df)
# Out:
# <AxesSubplot:xlabel='Reson of Abandon', ylabel='count'>

# %% [markdown]
# ### Conclusion- Switching the website from one to another is due to better alternative.

# %%
### Countplot to see the count of values
df['what Content easy to read?'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("what Content easy to read?", data=df)
# Out:
# <AxesSubplot:xlabel='what Content easy to read?', ylabel='count'>

# %% [markdown]
# ### Conclusion- Easy content to understand help more consumer to do shopping with accuracy.

# %%
### Countplot to see the count of values
df['Information need to highlight for comparison'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Information need to highlight for comparison", data=df)
# Out:
# <AxesSubplot:xlabel='Information need to highlight for comparison', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of consumer agree to product information is mandatory to highlight ot get product information easily and get product.

# %%
### Countplot to see the count of values
df['Important information of seller'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Important information of seller", data=df)
# Out:
# <AxesSubplot:xlabel='Important information of seller', ylabel='count'>

# %% [markdown]
# ### Conclusion- Important information for seller is an important factor to make shopping.

# %%
### Countplot to see the count of values
df['Information need to state clearly'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Information need to state clearly", data=df)
# Out:
# <AxesSubplot:xlabel='Information need to state clearly', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of consumer agree to product information is state clearly is strongly need by customer.

# %%
### Countplot to see the count of values
df['Ease of Negative'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Ease of Negative", data=df)
# Out:
# <AxesSubplot:xlabel='Ease of Negative', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of consumer strongly believe in ease of negative.

# %%
### Countplot to see the count of values
df['Speed'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Speed", data=df)
# Out:
# <AxesSubplot:xlabel='Speed', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of consumer strongly agreed that speed of the delivery is important to do shopping. It is an important feature for online shopping.

# %%
### Countplot to see the count of values
df['Interface'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Interface", data=df)
# Out:
# <AxesSubplot:xlabel='Interface', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of consumer strongly agreed that interface of the website of web store should be good.

# %%
### Countplot to see the count of values
df['Convenient Payment option'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Convenient Payment option", data=df)
# Out:
# <AxesSubplot:xlabel='Convenient Payment option', ylabel='count'>

# %% [markdown]
# ### Conclusion- Majority of consumer strongly agreed that payment mode should be convenient.

# %%
### Countplot to see the count of values
df['Trust on transaction'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Trust on transaction", data=df)
# Out:
# <AxesSubplot:xlabel='Trust on transaction', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of consumer strongly agreed that payment transaction should be safe and trustworthy.

# %%
### Countplot to see the count of values
df['Empathy'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Empathy", data=df)
# Out:
# <AxesSubplot:xlabel='Empathy', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of consumer strongly agreed that Eampthy should be good.

# %%
### Countplot to see the count of values
df['Privacy guarantee'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Privacy guarantee", data=df)
# Out:
# <AxesSubplot:xlabel='Privacy guarantee', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of consumer strongly agreed that Privacy gurantee should be stongly agreed.

# %%
### Countplot to see the count of values
df['Res, Avail of communication'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Res, Avail of communication", data=df)
# Out:
# <AxesSubplot:xlabel='Res, Avail of communication', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of consumer strongly agreed that availabilty of communication is also main factor to online shopping.

# %%
### Countplot to see the count of values
df['Benefit and Discounts'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Benefit and Discounts", data=df)
# Out:
# <AxesSubplot:xlabel='Benefit and Discounts', ylabel='count'>

# %% [markdown]
# ### Conclusion- Most of consumer strongly agreed that benefits and discount is also a main feature for online shopping.

# %%
### Countplot to see the count of values
df['Enjoyment'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Enjoyment", data=df)
# Out:
# <AxesSubplot:xlabel='Enjoyment', ylabel='count'>

# %% [markdown]
# ### Conclusion- Enjoyment with the website is also strongly agreed wtih most of the customer.

# %%
### Countplot to see the count of values
df['Convenient and Flexible'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Convenient and Flexible", data=df)
# Out:
# <AxesSubplot:xlabel='Convenient and Flexible', ylabel='count'>

# %% [markdown]
# ### Conclusion- Convienient and flexibilty with the website is also strongly agreed wtih most of the customer.

# %%
### Countplot to see the count of values
df['Is return, replace important'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Is return, replace important", data=df)
# Out:
# <AxesSubplot:xlabel='Is return, replace important', ylabel='count'>

# %% [markdown]
# ### Conclusion- Return and replacement is strongly needed from the aspect of the customer.

# %%
### Countplot to see the count of values
df['Loyalty Programs Benefits'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Loyalty Programs Benefits", data=df)
# Out:
# <AxesSubplot:xlabel='Loyalty Programs Benefits', ylabel='count'>

# %% [markdown]
# ### Conclusion- Loyality program benefits is strongly agreed from mostly customer.

# %%
### Countplot to see the count of values
df['Displaying Information'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Displaying Information", data=df)
# Out:
# <AxesSubplot:xlabel='Displaying Information', ylabel='count'>

# %% [markdown]
# ### Conclusion- Displaying information about product and seller is strongly agreed from mostly customer.

# %%
### Countplot to see the count of values
df['Good Quality Website'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Good Quality Website", data=df)
# Out:
# <AxesSubplot:xlabel='Good Quality Website', ylabel='count'>

# %% [markdown]
# ### Conclusion- Good quality of the webiste is strongly agreed from mostly customer.

# %%
### Countplot to see the count of values
df['Net Benefit'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Net Benefit", data=df)
# Out:
# <AxesSubplot:xlabel='Net Benefit', ylabel='count'>

# %% [markdown]
# ### Conclusion- Net Benefit on purchase is strongly agreed from mostly customer.

# %%
### Countplot to see the count of values
df['Satisfaction/Trust'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Satisfaction/Trust", data=df)
# Out:
# <AxesSubplot:xlabel='Satisfaction/Trust', ylabel='count'>

# %% [markdown]
# ### Conclusion- Staifaction and trust with product is strongly agreed from mostly customer.

# %%
### Countplot to see the count of values
df['Wide variety'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Wide variety", data=df)
# Out:
# <AxesSubplot:xlabel='Wide variety', ylabel='count'>

# %% [markdown]
# ### Conclusion- Wide Varity on product is strongly agreed from mostly customer.

# %%
### Countplot to see the count of values
df['Relevant product information'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Relevant product information", data=df)
# Out:
# <AxesSubplot:xlabel='Relevant product information', ylabel='count'>

# %% [markdown]
# ### Conclusion- Revelent Product information is strongly agreed from mostly customer.

# %%
### Countplot to see the count of values
df['Monetary savings'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Monetary savings", data=df)
# Out:
# <AxesSubplot:xlabel='Monetary savings', ylabel='count'>

# %% [markdown]
# ### Conclusion- Monetary saving is strongly agreed from mostly customer.

# %%
### Countplot to see the count of values
df['Patronizing'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Patronizing", data=df)
# Out:
# <AxesSubplot:xlabel='Patronizing', ylabel='count'>

# %% [markdown]
# ### Conclusion- Patronizing is strongly agreed from mostly customer.

# %%
### Countplot to see the count of values
df['Sense of Adventure'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Sense of Adventure", data=df)
# Out:
# <AxesSubplot:xlabel='Sense of Adventure', ylabel='count'>

# %% [markdown]
# ### Conclusion- Sense of adventure is strongly agreed from mostly customer.

# %%
### Countplot to see the count of values
df['Preferred e-tailer'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Preferred e-tailer", data=df)
# Out:
# <AxesSubplot:xlabel='Preferred e-tailer', ylabel='count'>

# %% [markdown]
# ### Conclusion- Preferred E-Tailer is indifferent with most of the customer.

# %%
### Countplot to see the count of values
df['Gratification'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Gratification", data=df)
# Out:
# <AxesSubplot:xlabel='Gratification', ylabel='count'>

# %% [markdown]
# ### Conclusion- Gratification is indifferent with most of the customer.

# %%
### Countplot to see the count of values
df['Value for money spent'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Value for money spent", data=df)
# Out:
# <AxesSubplot:xlabel='Value for money spent', ylabel='count'>

# %% [markdown]
# ### Conclusion- Value for money spent is agreed with most of the customer.

# %%
### Countplot to see the count of values
df['Helps you fulfill certain roles'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Helps you fulfill certain roles", data=df)
# Out:
# <AxesSubplot:xlabel='Helps you fulfill certain roles', ylabel='count'>

# %% [markdown]
# ### Conclusion- Helps you fullfill certain roles is agreed with most of the customer.

# %%
### Countplot to see the count of values
df['Tick'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: Tick, dtype: int64

# %%
### Countplot to see the count of values
df['Web-page Layout'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Myntra.com                                                      15
# Amazon.in, Myntra.com                                           15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Web-page Layout, dtype: int64

# %%
### Countplot to see the count of values
df['Website/Application'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com                                         44
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Website/Application, dtype: int64

# %%
### Countplot to see the count of values
df['Wild variety'].value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Myntra.com                                            15
# Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety, dtype: int64

# %%
### Countplot to see the count of values
df['Product Information'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Product Information, dtype: int64

# %%
### Countplot to see the count of values
df['Website loading speed'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Website loading speed, dtype: int64

# %%
### Countplot to see the count of values
df['Reliability'].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability, dtype: int64

# %%
### Countplot to see the count of values
df['Quickness to purchase'].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to purchase, dtype: int64

# %%
### Countplot to see the count of values
df['several payment options'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: several payment options, dtype: int64

# %%
### Countplot to see the count of values
df['Privacy'].value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Myntra.com                                                      15
# Amazon.in, Paytm.com                                            15
# Flipkart.com                                                    15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy, dtype: int64

# %%
### Countplot to see the count of values
df['Security for financial info'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security for financial info, dtype: int64

# %%
### Countplot to see the count of values
df['Perceived Trustworthiness'].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
### Countplot to see the count of values
df['Website loading speed'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Website loading speed, dtype: int64

# %%
### Countplot to see the count of values
df['Time to get logged'].value_counts()
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Time to get logged, dtype: int64

# %%
### Countplot to see the count of values
df['Time in displaying graphics'].value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Time in displaying graphics, dtype: int64

# %%
### Countplot to see the count of values
df['Late declaration of price'].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Amazon.in                  38
# Flipkart.com               38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price, dtype: int64

# %%
### Countplot to see the count of values
df['Page loading time'].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Page loading time, dtype: int64

# %%
### Countplot to see the count of values
df['Delivery period'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Delivery period", data=df)
# Out:
# <AxesSubplot:xlabel='Delivery period', ylabel='count'>

# %% [markdown]
# ### Conclusion- Delivery Period is best for Paytm comparison to other online store.

# %%
### Countplot to see the count of values
df['Change in website/Application'].value_counts()
plt.figure(figsize=(12,8))
sns.countplot("Change in website/Application", data=df)
# Out:
# <AxesSubplot:xlabel='Change in website/Application', ylabel='count'>

# %% [markdown]
# ### Conclusion- Customer generally need change in amanzon and Paytm.com website.

# %%
### Countplot to see the count of values
df['Frequent disruption'].value_counts()
plt.figure(figsize=(25,15))
sns.countplot("Frequent disruption", data=df)
# Out:
# <AxesSubplot:xlabel='Frequent disruption', ylabel='count'>

# %% [markdown]
# ### Conclusion- Amazon,myntra and snapdeal has more disruption compared to other.

# %%
### Countplot to see the count of values
df['efficient as before'].value_counts()
plt.figure(figsize=(25,15))
sns.countplot("efficient as before", data=df)
# Out:
# <AxesSubplot:xlabel='efficient as before', ylabel='count'>

# %% [markdown]
# ### Conclusion- Amazon is only website Efficient as before compare to others.

# %%
### Countplot to see the count of values
df['Recommend Indian online retailer'].value_counts()
plt.figure(figsize=(25,15))
sns.countplot("Recommend Indian online retailer", data=df)
# Out:
# <AxesSubplot:xlabel='Recommend Indian online retailer', ylabel='count'>

# %% [markdown]
# ### Conclusion- Amazon and flipkart has more refferal than other online seller.

# %% [markdown]
# ### Mostly columns are object, first change into integer.

# %%
df.dtypes
# Out:
# Gender                                          object
# Age                                             object
# City                                            object
# Pin                                              int64
# Shopping Since                                  object
# Purchase in past 1 Year                         object
# Internet service used                           object
# Device                                          object
# Screen Size of used device                      object
# Device OS                                       object
# Browser                                         object
# Channel which direct to website                 object
# How to reach store                              object
# Time taken to make decision                     object
# Payment Option                                  object
# Abandon                                         object
# Reson of Abandon                                object
# ...

# %%
###Importing the Labelencoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in df.columns:
    if df[col].dtypes == 'object':
        df[col] = le.fit_transform(df[col])

# %%
df.dtypes
# Out:
# Gender                                          int32
# Age                                             int32
# City                                            int32
# Pin                                             int64
# Shopping Since                                  int32
# Purchase in past 1 Year                         int32
# Internet service used                           int32
# Device                                          int32
# Screen Size of used device                      int32
# Device OS                                       int32
# Browser                                         int32
# Channel which direct to website                 int32
# How to reach store                              int32
# Time taken to make decision                     int32
# Payment Option                                  int32
# Abandon                                         int32
# Reson of Abandon                                int32
# ...

# %% [markdown]
# ### Now all the datatypes are changed.Now Proceeding further.

# %% [markdown]
# ## Checking the multicolinearity

# %%
plt.figure(figsize=(30,25))
sns.heatmap(df.corr(), annot=True, fmt='.2f', linewidths=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### As the number of columns are 71. So, we are not able to analysis the multicolinearity. So, we wil check with numeric presentation.

# %%
df.corr()
# Out:
#                                                 Gender       Age      City  \
# Gender                                        1.000000  0.046169  0.080912
# Age                                           0.046169  1.000000  0.113712
# City                                          0.080912  0.113712  1.000000
# Pin                                          -0.260365 -0.120704 -0.416597
# Shopping Since                               -0.057096 -0.087847 -0.138329
# Purchase in past 1 Year                       0.077876  0.309575  0.173871
# Internet service used                        -0.309029  0.255594 -0.010436
# Device                                        0.061673  0.022383  0.020650
# Screen Size of used device                    0.028794 -0.006101  0.199296
# Device OS                                    -0.019243 -0.048087 -0.051642
# Browser                                       0.071385 -0.231530 -0.051933
# ...

# %% [markdown]
# ### Some columns has multicolinearity but no need to drop any column.

# %% [markdown]
# ### Checking the Values distribution through distplot.

# %%
df.plot(kind='density', subplots=True, figsize=(20,15), layout = (6,12), fontsize =2, sharex=False, legend= False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Most of the feature has normal distribution but has some skewness either left or right. So, I will check skewness once and then remove.

# %%
df.skew()
# Out:
# Gender                                          0.741028
# Age                                             0.680987
# City                                            0.313729
# Pin                                             1.748322
# Shopping Since                                 -0.276968
# Purchase in past 1 Year                        -0.421739
# Internet service used                          -0.361630
# Device                                         -0.485180
# Screen Size of used device                     -1.308503
# Device OS                                      -0.270283
# Browser                                         1.710244
# Channel which direct to website                -2.469485
# How to reach store                             -0.041161
# Time taken to make decision                    -0.390691
# Payment Option                                  0.129735
# Abandon                                        -0.867449
# ...

# %% [markdown]
# ### Some of features has skewness but these features are categorical features. So, I dont need to remove any skewness.

# %% [markdown]
# ### Checking the outliers

# %%
plt.figure(figsize=(25,22))
pn = 1
for column in df:
    if pn <= 72:
        ax = plt.subplot(10,8, pn)
        sns.boxplot(df[column], orient='v')
        plt.xlabel(column, fontsize=10)
    pn+=1
plt.tight_layout()

# %% [markdown]
# ### No feature has outliers, those feature has outliers which has categorical values. So, the some outliers are exceptable.

# %% [markdown]
# ### My analysis done here.
#
# ## Conslusion-  According to my analysis with this dataset is that Two online stores are mostly in demand and which is Amazon and Flipkart. Customer base is daily increase, Every year number of customer increasing for online shopping.
